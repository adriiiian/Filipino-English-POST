# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Result Evaluation

# %% [markdown]
# Reading the input file

# %%
input_dataframe = pd.read_json("input/englishmonolingualtext.json")
display(input_dataframe)
# Out:
#                                      0                                     1   \
# 0        {'token': 'This', 'tag': 'DT'}         {'token': 'may', 'tag': 'MD'}
# 1          {'token': 'If', 'tag': 'IN'}         {'token': 'you', 'tag': 'PR'}
# 2     {'token': 'Message', 'tag': 'VB'}          {'token': 'me', 'tag': 'PR'}
# 3      {'token': 'Please', 'tag': 'UH'}   {'token': 'enlighten', 'tag': 'VB'}
# 4        {'token': 'This', 'tag': 'DT'}          {'token': 'is', 'tag': 'VB'}
# 5      {'token': 'Budget', 'tag': 'VB'}         {'token': '20k', 'tag': 'CD'}
# 6         {'token': 'Any', 'tag': 'DT'}      {'token': 'tips', 'tag': 'NOUN'}
# 7        {'token': 'This', 'tag': 'DT'}        {'token': 'will', 'tag': 'MD'}
# 8        {'token': 'Also', 'tag': 'RB'}         {'token': ',', 'tag': 'PUNC'}
# 9          {'token': 'LF', 'tag': 'VB'}   {'token': 'someone', 'tag': 'NOUN'}
# 10        {'token': 'The', 'tag': 'DT'}   {'token': 'Tukomi', 'tag': 'PROPN'}
# 11        {'token': 'Was', 'tag': 'VB'}   {'token': 'searching', 'tag': 'VB'}
# 12        {'token': 'Any', 'tag': 'DT'}  {'token': 'insights', 'tag': 'NOUN'}
# 13         {'token': 'If', 'tag': 'IN'}          {'token': 'it', 'tag': 'PR'}
# 14         {'token': 'To', 'tag': 'TO'}   {'token': 'surrender', 'tag': 'VB'}
# 15         {'token': 'If', 'tag': 'IN'}          {'token': 'so', 'tag': 'RB'}
# 16         {'token': 'Is', 'tag': 'VB'}          {'token': 'it', 'tag': 'PR'}
# 17         {'token': 'Is', 'tag': 'VB'}          {'token': 'it', 'tag': 'PR'}
# 18        {'token': 'The', 'tag': 'DT'}     {'token': 'current', 'tag': 'JJ'}
# 19         {'token': 'Is', 'tag': 'VB'}       {'token': 'there', 'tag': 'EX'}
# 20       {'token': 'Just', 'tag': 'RB'}        {'token': 'send', 'tag': 'VB'}
# 21      {'token': 'About', 'tag': 'IN'}         {'token': 'you', 'tag': 'PR'}
# 22        {'token': 'The', 'tag': 'DT'}    {'token': 'lesson', 'tag': 'NOUN'}
# 23          {'token': 'I', 'tag': 'PR'}          {'token': 'am', 'tag': 'VB'}
# 24  {'token': 'Medicated', 'tag': 'VB'}  {'token': 'bandages', 'tag': 'NOUN'}
# 25        {'token': 'The', 'tag': 'DT'}   {'token': 'begonia', 'tag': 'NOUN'}
#
#                                     2                                     3   \
# 0         {'token': 'be', 'tag': 'VB'}           {'token': 'a', 'tag': 'DT'}
# 1        {'token': 'are', 'tag': 'VB'}          {'token': '18', 'tag': 'CD'}
# 2       {'token': 'or', 'tag': 'CONJ'}        {'token': 'text', 'tag': 'VB'}
# 3         {'token': 'me', 'tag': 'PR'}   {'token': 'regarding', 'tag': 'VB'}
# 4        {'token': 'not', 'tag': 'RB'}           {'token': 'a', 'tag': 'DT'}
# 5          {'token': 'a', 'tag': 'DT'}     {'token': 'month', 'tag': 'NOUN'}
# 6     {'token': 'guys', 'tag': 'NOUN'}         {'token': 'how', 'tag': 'RB'}
# 7         {'token': 'be', 'tag': 'VB'}          {'token': 'my', 'tag': 'PR'}
# 8        {'token': 'why', 'tag': 'RB'}     {'token': 'entrust', 'tag': 'VB'}
# 9     {'token': 'petite', 'tag': 'JJ'}          {'token': 'to', 'tag': 'TO'}
# 10   {'token': 'video', 'tag': 'NOUN'}  {'token': 'advertises', 'tag': 'VB'}
# 11       {'token': 'for', 'tag': 'IN'}     {'token': 'intense', 'tag': 'JJ'}
# 12        {'token': 'on', 'tag': 'IN'}        {'token': 'this', 'tag': 'DT'}
# 13   {'token': 'matters', 'tag': 'VB'}         {'token': ',', 'tag': 'PUNC'}
# 14       {'token': 'all', 'tag': 'DT'}   {'token': 'desires', 'tag': 'NOUN'}
# 15       {'token': ',', 'tag': 'PUNC'}         {'token': 'you', 'tag': 'PR'}
# 16   {'token': 'because', 'tag': 'IN'}          {'token': 'of', 'tag': 'IN'}
# 17  {'token': 'possible', 'tag': 'JJ'}          {'token': 'to', 'tag': 'TO'}
# 18   {'token': 'trend', 'tag': 'NOUN'}       {'token': 'right', 'tag': 'RB'}
# 19       {'token': 'any', 'tag': 'DT'}       {'token': 'way', 'tag': 'NOUN'}
# 20         {'token': 'a', 'tag': 'DT'}   {'token': 'message', 'tag': 'NOUN'}
# 21        {'token': ':', 'tag': 'SYM'}           {'token': 'A', 'tag': 'DT'}
# 22      {'token': 'will', 'tag': 'VB'}       {'token': 'cover', 'tag': 'VB'}
# 23      {'token': 'just', 'tag': 'RB'}   {'token': 'genuinely', 'tag': 'RB'}
# 24       {'token': 'can', 'tag': 'MD'}          {'token': 'be', 'tag': 'VB'}
# 25     {'token': 'and', 'tag': 'CONJ'}  {'token': 'lavender', 'tag': 'NOUN'}
#
#                                          4   \
# 0      {'token': 'misleading', 'tag': 'JJ'}
# 1              {'token': '-', 'tag': 'SYM'}
# 2              {'token': 'me', 'tag': 'PR'}
# 3            {'token': 'this', 'tag': 'DT'}
# 4        {'token': 'hookup', 'tag': 'NOUN'}
# 5             {'token': 'Max', 'tag': 'JJ'}
# 6              {'token': 'to', 'tag': 'TO'}
# 7           {'token': 'first', 'tag': 'JJ'}
# 8             {'token': 'the', 'tag': 'DT'}
# 9            {'token': 'fuck', 'tag': 'VB'}
# 10              {'token': 'a', 'tag': 'DT'}
# 11  {'token': 'programming', 'tag': 'NOUN'}
# 12            {'token': '?', 'tag': 'PUNC'}
# 13              {'token': 'I', 'tag': 'PR'}
# 14          {'token': 'and', 'tag': 'CONJ'}
# 15         {'token': 'guys', 'tag': 'NOUN'}
# 16            {'token': 'the', 'tag': 'DT'}
# 17            {'token': 'not', 'tag': 'RB'}
# 18            {'token': 'now', 'tag': 'RB'}
# 19             {'token': 'to', 'tag': 'TO'}
# 20             {'token': 'if', 'tag': 'IN'}
# 21     {'token': 'biological', 'tag': 'JJ'}
# 22              {'token': '1', 'tag': 'CD'}
# 23        {'token': 'curious', 'tag': 'JJ'}
# 24           {'token': 'used', 'tag': 'VB'}
# 25            {'token': ',', 'tag': 'PUNC'}
#
#                                             5   \
# 0            {'token': 'title', 'tag': 'NOUN'}
# 1                 {'token': '30', 'tag': 'CD'}
# 2                 {'token': '(', 'tag': 'SYM'}
# 3           {'token': 'matter', 'tag': 'NOUN'}
# 4             {'token': 'post', 'tag': 'NOUN'}
# 5                {'token': '.', 'tag': 'PUNC'}
# 6             {'token': 'handle', 'tag': 'VB'}
# 7             {'token': 'time', 'tag': 'NOUN'}
# 8   {'token': 'implementation', 'tag': 'NOUN'}
# 9                {'token': '.', 'tag': 'PUNC'}
# 10            {'token': '1-year', 'tag': 'CD'}
# 11            {'token': 'jobs', 'tag': 'NOUN'}
# 12                                        None
# 13                {'token': ''m', 'tag': 'VB'}
# 14              {'token': 'only', 'tag': 'RB'}
# 15               {'token': 'can', 'tag': 'MD'}
# 16             {'token': 'UG', 'tag': 'PROPN'}
# 17            {'token': 'choose', 'tag': 'VB'}
# 18                {'token': 'is', 'tag': 'VB'}
# 19           {'token': 'restore', 'tag': 'VB'}
# 20               {'token': 'you', 'tag': 'PR'}
# 21           {'token': 'woman', 'tag': 'NOUN'}
# 22               {'token': '.', 'tag': 'PUNC'}
# 23               {'token': '.', 'tag': 'PUNC'}
# 24                {'token': 'on', 'tag': 'IN'}
# 25          {'token': 'danger', 'tag': 'NOUN'}
#
#                                            6   \
# 0               {'token': '.', 'tag': 'PUNC'}
# 1             {'token': 'yrs', 'tag': 'NOUN'}
# 2       {'token': '09175418046', 'tag': 'CD'}
# 3               {'token': '.', 'tag': 'PUNC'}
# 4               {'token': 'btw', 'tag': 'UH'}
# 5                                        None
# 6              {'token': 'this', 'tag': 'DT'}
# 7          {'token': 'ordering', 'tag': 'VB'}
# 8                {'token': 'of', 'tag': 'IN'}
# 9                                        None
# 10     {'token': 'investment', 'tag': 'NOUN'}
# 11             {'token': 'like', 'tag': 'IN'}
# 12                                       None
# 13                {'token': 'a', 'tag': 'DT'}
# 14             {'token': 'then', 'tag': 'RB'}
# 15            {'token': 'share', 'tag': 'VB'}
# 16            {'token': 'rap', 'tag': 'NOUN'}
# 17                {'token': 'a', 'tag': 'DT'}
# 18              {'token': 'the', 'tag': 'DT'}
# 19             {'token': 'said', 'tag': 'VB'}
# 20              {'token': ''re', 'tag': 'VB'}
# 21              {'token': '.', 'tag': 'PUNC'}
# 22  {'token': 'pronunciation', 'tag': 'NOUN'}
# 23                                       None
# 24          {'token': 'burns', 'tag': 'NOUN'}
# 25            {'token': 'and', 'tag': 'PUNC'}
#
#                                          7   \
# 0                                      None
# 1             {'token': 'old', 'tag': 'JJ'}
# 2              {'token': ')', 'tag': 'SYM'}
# 3                                      None
# 4             {'token': '.', 'tag': 'PUNC'}
# 5                                      None
# 6             {'token': '?', 'tag': 'PUNC'}
# 7          {'token': 'online', 'tag': 'RB'}
# 8   {'token': 'vaccination', 'tag': 'NOUN'}
# 9                                      None
# 10         {'token': 'return', 'tag': 'VB'}
# 11   {'token': 'eCommerce', 'tag': 'PROPN'}
# 12                                     None
# 13          {'token': 'dom', 'tag': 'NOUN'}
# 14            {'token': 'can', 'tag': 'MD'}
# 15             {'token': 'it', 'tag': 'PR'}
# 16       {'token': 'battle', 'tag': 'NOUN'}
# 17    {'token': 'candidate', 'tag': 'NOUN'}
# 18       {'token': 'diskless', 'tag': 'JJ'}
# 19       {'token': 'photos', 'tag': 'NOUN'}
# 20              {'token': 'G', 'tag': 'JJ'}
# 21          {'token': 'Being', 'tag': 'VB'}
# 22              {'token': '2', 'tag': 'CD'}
# 23                                     None
# 24            {'token': '.', 'tag': 'PUNC'}
# 25    {'token': 'suspicion', 'tag': 'NOUN'}
#
#                                     8   \
# 0                                 None
# 1        {'token': '.', 'tag': 'PUNC'}
# 2         {'token': 'if', 'tag': 'IN'}
# 3                                 None
# 4                                 None
# 5                                 None
# 6                                 None
# 7    {'token': 'outside', 'tag': 'IN'}
# 8    {'token': 'slots', 'tag': 'NOUN'}
# 9                                 None
# 10        {'token': 'of', 'tag': 'IN'}
# 11       {'token': ',', 'tag': 'PUNC'}
# 12                                None
# 13       {'token': ',', 'tag': 'PUNC'}
# 14       {'token': 'one', 'tag': 'PR'}
# 15      {'token': 'here', 'tag': 'RB'}
# 16       {'token': '?', 'tag': 'PUNC'}
# 17       {'token': '?', 'tag': 'PUNC'}
# 18  {'token': 'system', 'tag': 'NOUN'}
# 19        {'token': '&', 'tag': 'SYM'}
# 20                                None
# 21  {'token': 'petite', 'tag': 'NOUN'}
# 22       {'token': '.', 'tag': 'PUNC'}
# 23                                None
# 24                                None
# 25       {'token': ',', 'tag': 'PUNC'}
#
#                                         9   \
# 0                                     None
# 1                                     None
# 2            {'token': 'you', 'tag': 'PR'}
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7            {'token': 'the', 'tag': 'DT'}
# 8             {'token': 'to', 'tag': 'TO'}
# 9                                     None
# 10          {'token': '2800', 'tag': 'CD'}
# 11   {'token': 'inventory', 'tag': 'NOUN'}
# 12                                    None
# 13         {'token': 'daddy', 'tag': 'JJ'}
# 14          {'token': 'find', 'tag': 'VB'}
# 15           {'token': '.', 'tag': 'PUNC'}
# 16                                    None
# 17                                    None
# 18         {'token': 'right', 'tag': 'JJ'}
# 19      {'token': 'videos', 'tag': 'NOUN'}
# 20                                    None
# 21            {'token': 'is', 'tag': 'VB'}
# 22                                    None
# 23                                    None
# 24                                    None
# 25  {'token': 'respectively', 'tag': 'RB'}
#
#                                      10                                 11  \
# 0                                  None                               None
# 1                                  None                               None
# 2        {'token': 'want', 'tag': 'VB'}       {'token': 'to', 'tag': 'TO'}
# 3                                  None                               None
# 4                                  None                               None
# 5                                  None                               None
# 6                                  None                               None
# 7   {'token': 'country', 'tag': 'NOUN'}      {'token': '.', 'tag': 'PUNC'}
# 8        {'token': 'this', 'tag': 'DT'}   {'token': 'faulty', 'tag': 'JJ'}
# 9                                  None                               None
# 10         {'token': '%', 'tag': 'SYM'}      {'token': '.', 'tag': 'PUNC'}
# 11   {'token': 'system', 'tag': 'NOUN'}      {'token': ',', 'tag': 'PUNC'}
# 12                                 None                               None
# 13      {'token': 'dom', 'tag': 'NOUN'}      {'token': ',', 'tag': 'PUNC'}
# 14      {'token': 'inner', 'tag': 'JJ'}  {'token': 'peace', 'tag': 'NOUN'}
# 15                                 None                               None
# 16                                 None                               None
# 17                                 None                               None
# 18        {'token': '?', 'tag': 'PUNC'}                               None
# 19        {'token': '?', 'tag': 'PUNC'}                               None
# 20                                 None                               None
# 21          {'token': 'a', 'tag': 'DT'}   {'token': 'plus', 'tag': 'NOUN'}
# 22                                 None                               None
# 23                                 None                               None
# 24                                 None                               None
# 25        {'token': '.', 'tag': 'PUNC'}                               None
#
#                                         12  \
# 0                                     None
# 1                                     None
# 2           {'token': 'help', 'tag': 'VB'}
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8   {'token': 'eZConsult', 'tag': 'PROPN'}
# 9                                     None
# 10                                    None
# 11         {'token': 'etc', 'tag': 'NOUN'}
# 12                                    None
# 13      {'token': 'actually', 'tag': 'RB'}
# 14          {'token': 'or', 'tag': 'PUNC'}
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21         {'token': 'but', 'tag': 'CONJ'}
# 22                                    None
# 23                                    None
# 24                                    None
# 25                                    None
#
#                                     13                                   14  \
# 0                                 None                                 None
# 1                                 None                                 None
# 2        {'token': 'out', 'tag': 'RB'}       {'token': 'with', 'tag': 'IN'}
# 3                                 None                                 None
# 4                                 None                                 None
# 5                                 None                                 None
# 6                                 None                                 None
# 7                                 None                                 None
# 8      {'token': 'app', 'tag': 'NOUN'}        {'token': '?', 'tag': 'PUNC'}
# 9                                 None                                 None
# 10                                None                                 None
# 11       {'token': '.', 'tag': 'PUNC'}                                 None
# 12                                None                                 None
# 13       {'token': '.', 'tag': 'PUNC'}                                 None
# 14  {'token': 'whatever', 'tag': 'PR'}        {'token': '.', 'tag': 'PUNC'}
# 15                                None                                 None
# 16                                None                                 None
# 17                                None                                 None
# 18                                None                                 None
# 19                                None                                 None
# 20                                None                                 None
# 21       {'token': 'not', 'tag': 'RB'}  {'token': 'preferred', 'tag': 'VB'}
# 22                                None                                 None
# 23                                None                                 None
# 24                                None                                 None
# 25                                None                                 None
#
#                                 15                                   16  \
# 0                             None                                 None
# 1                             None                                 None
# 2   {'token': 'this', 'tag': 'DT'}  {'token': 'passion', 'tag': 'NOUN'}
# 3                             None                                 None
# 4                             None                                 None
# 5                             None                                 None
# 6                             None                                 None
# 7                             None                                 None
# 8                             None                                 None
# 9                             None                                 None
# 10                            None                                 None
# 11                            None                                 None
# 12                            None                                 None
# 13                            None                                 None
# 14                            None                                 None
# 15                            None                                 None
# 16                            None                                 None
# 17                            None                                 None
# 18                            None                                 None
# 19                            None                                 None
# 20                            None                                 None
# 21   {'token': '.', 'tag': 'PUNC'}     {'token': 'Around', 'tag': 'IN'}
# 22                            None                                 None
# 23                            None                                 None
# 24                            None                                 None
# 25                            None                                 None
#
#                                      17                               18  \
# 0                                  None                             None
# 1                                  None                             None
# 2   {'token': 'project', 'tag': 'NOUN'}    {'token': '.', 'tag': 'PUNC'}
# 3                                  None                             None
# 4                                  None                             None
# 5                                  None                             None
# 6                                  None                             None
# 7                                  None                             None
# 8                                  None                             None
# 9                                  None                             None
# 10                                 None                             None
# 11                                 None                             None
# 12                                 None                             None
# 13                                 None                             None
# 14                                 None                             None
# 15                                 None                             None
# 16                                 None                             None
# 17                                 None                             None
# 18                                 None                             None
# 19                                 None                             None
# 20                                 None                             None
# 21      {'token': 'age', 'tag': 'NOUN'}  {'token': '20-35', 'tag': 'CD'}
# 22                                 None                             None
# 23                                 None                             None
# 24                                 None                             None
# 25                                 None                             None
#
#                                19
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# 5                            None
# 6                            None
# 7                            None
# 8                            None
# 9                            None
# 10                           None
# 11                           None
# 12                           None
# 13                           None
# 14                           None
# 15                           None
# 16                           None
# 17                           None
# 18                           None
# 19                           None
# 20                           None
# 21  {'token': '.', 'tag': 'PUNC'}
# 22                           None
# 23                           None
# 24                           None
# 25                           None

# %% [markdown]
# Reading the output files

# %%
ff_combi1_output = pd.read_csv("output/monolingual_eng/Flair-FSPOST-Combination-1-monolingual_eng.csv")
ff_combi2_output = pd.read_csv("output/monolingual_eng/Flair-FSPOST-Combination-2-monolingual_eng.csv")
sf_combi1_output = pd.read_csv("output/monolingual_eng/Spacy-FSPOST-Combination-1-monolingual_eng.csv")
sf_combi2_output = pd.read_csv("output/monolingual_eng/Spacy-FSPOST-Combination-2-monolingual_eng.csv")

# %% [markdown]
# Functions to be used for results evaluation

# %%
def fixed_columns(output):
    output['general_tags'] = output['general_tags'].apply(eval)
    output['specific_tags'] = output['specific_tags'].apply(eval)
    output['token_tagset'] = output['token_tagset'].apply(eval)
    
    return output

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])

# %%
ff_combi1_output = fixed_columns(ff_combi1_output)
ff_combi2_output = fixed_columns(ff_combi2_output)
sf_combi1_output = fixed_columns(sf_combi1_output)
sf_combi2_output = fixed_columns(sf_combi2_output)

# %%
ff_combi1_tag_counts = to_1D(ff_combi1_output['general_tags']).value_counts()
ff_combi1_total = ff_combi1_tag_counts.sum()

ff_combi2_tag_counts = to_1D(ff_combi2_output['general_tags']).value_counts()
ff_combi2_total = ff_combi2_tag_counts.sum()

sf_combi1_tag_counts = to_1D(sf_combi1_output['general_tags']).value_counts()
sf_combi1_total = sf_combi1_tag_counts.sum()

sf_combi2_tag_counts = to_1D(sf_combi2_output['general_tags']).value_counts()
sf_combi2_total = sf_combi2_tag_counts.sum()

# %%
def print_tag_counts(tag_counts, total, tagger):
    print(tag_counts)
    print(tagger, " total tokens: ", total, "\n")

# %%
print_tag_counts(ff_combi1_tag_counts, ff_combi1_total, "Flair-FSPOST Combi1")
print_tag_counts(ff_combi2_tag_counts, ff_combi2_total, "Flair-FSPOST Combi2")
print_tag_counts(sf_combi1_tag_counts, sf_combi1_total, "Spacy-FSPOST Combi1")
print_tag_counts(sf_combi2_tag_counts, sf_combi2_total, "Spacy-FSPOST Combi2")
# Out:
# NOUN     73
# PUNC     37
# RB       22
# DT       18
# VB       14
# VBPR     13
# PR       13
# IN       11
# CD       11
# PROPN     9
# JJ        9
# UH        7
# CONJ      7
# XX        6
# FW        6
# SYM       6
# VBPT      4
# MD        2
# TO        1
# Name: count, dtype: int64
# Flair-FSPOST Combi1  total tokens:  269
#
# NOUN     53
# PUNC     39
# FW       20
# DT       18
# RB       18
# VB       18
# IN       16
# PR       15
# VBPR     14
# JJ       11
# CD       10
# PROPN     9
# SYM       7
# CONJ      6
# TO        6
# VBPT      5
# MD        2
# UH        1
# EX        1
# Name: count, dtype: int64
# Flair-FSPOST Combi2  total tokens:  269
#
# NOUN     64
# PUNC     37
# RB       24
# DT       18
# VB       18
# PROPN    14
# VBPR     14
# PR       13
# CD       12
# IN       11
# JJ        8
# CONJ      7
# TO        7
# SYM       6
# FW        6
# UH        4
# VBPT      4
# MD        2
# Name: count, dtype: int64
# Spacy-FSPOST Combi1  total tokens:  269
#
# NOUN     48
# PUNC     38
# FW       20
# DT       19
# RB       19
# JJ       17
# VB       17
# IN       15
# VBPR     15
# PR       14
# CD       11
# PROPN     9
# SYM       8
# CONJ      6
# TO        6
# VBPT      3
# MD        2
# UH        1
# EX        1
# Name: count, dtype: int64
# Spacy-FSPOST Combi2  total tokens:  269

# %% [markdown]
# Overall Accuracy

# %%
pos_temp = []
tags_list = []

for i in range(len(input_dataframe)):
    pos_temp.clear()
    
    for j in range(input_dataframe.iloc[i].count()):
        pos_temp.append(input_dataframe.iloc[i][j].__getitem__("tag"))
    
    temp = np.array(pos_temp)
    tags_list.append(temp)

# %%
test_data_counts = to_1D(tags_list).value_counts()
test_data_counts_total = test_data_counts.sum()

print_tag_counts(test_data_counts, test_data_counts_total, "Test data counts")
# Out:
# NOUN     51
# VB       43
# PUNC     39
# DT       29
# RB       19
# IN       17
# PR       17
# JJ       16
# CD        9
# TO        7
# SYM       6
# MD        5
# CONJ      4
# PROPN     4
# UH        2
# EX        1
# Name: count, dtype: int64
# Test data counts  total tokens:  269

# %%
def get_overall_accuracy(output):
    accuracy = []
    for i in range(len(tags_list)):
        counter = 0
        for j in range(len(tags_list[i])):
            if tags_list[i][j] == output['general_tags'][i][j]:
                counter = counter + 1
                
        accuracy.append(counter / len(tags_list[i]))
        
    return accuracy

# %%
def print_overall_accuracy(output, tagger):
    accuracy = get_overall_accuracy(output)
    print(tagger, ' accuracy: %f' % (sum(accuracy) / len(accuracy)))

# %%
print_overall_accuracy(ff_combi1_output, "Flair-FSPOST Combi1")
print_overall_accuracy(sf_combi1_output, "Spacy-FSPOST Combi1")
print_overall_accuracy(ff_combi2_output, "Flair-FSPOST Combi2")
print_overall_accuracy(sf_combi2_output, "Spacy-FSPOST Combi2")
# Out:
# Flair-FSPOST Combi1  accuracy: 0.681472
# Spacy-FSPOST Combi1  accuracy: 0.692180
# Flair-FSPOST Combi2  accuracy: 0.746852
# Spacy-FSPOST Combi2  accuracy: 0.734489

# %% [markdown]
# Taking the Accuracy per POS tag

# %%
possible_tags = ['NOUN', 'PROPN', 'PR', 'DT', 'LM', 'CONJ', 'CCP', 'IN', 'VB', 'JJ', 'CD', 'RB', 'UH',
                  'TS', 'FW', 'PUNC', 'SYM', 'EX', 'TO', 'ADD', 'POS', 'PDT', 'XX', 'MD', 'AFX']

# %%
def get_accuracy_per_tags(output, tag):
    counter_right = 0
    counter_total = 0
    for i in range(len(tags_list)):
        for j in range(len(tags_list[i])):
            if tags_list[i][j] == tag:
                counter_total = counter_total + 1
                if tags_list[i][j] == 'VB':
                    if (output['general_tags'][i][j] == 'VB' or output['general_tags'][i][j] == 'VBPT' or
                    output['general_tags'][i][j] == 'VBPR' or output['general_tags'][i][j] == 'VBFT'):
                        counter_right = counter_right + 1
                elif tags_list[i][j] == output['general_tags'][i][j]:
                    counter_right = counter_right + 1
    
    if counter_total == 0:
        return None
    else:
        return counter_right / counter_total * 100

# %%
def print_accuracy_per_tags(output, tagger):
    print("Tagger: ", tagger)
    for i in range(len(possible_tags)):
        accuracy = get_accuracy_per_tags(output, possible_tags[i])
        if accuracy != None:
            print('POS Tag: ', possible_tags[i], ' accuracy: %f' % accuracy)
            
    print("\n")

# %%
print_accuracy_per_tags(ff_combi1_output, "Flair-FSPOST Combi1")
print_accuracy_per_tags(sf_combi1_output, "Spacy-FSPOST Combi1")
print_accuracy_per_tags(ff_combi2_output, "Flair-FSPOST Combi2")
print_accuracy_per_tags(sf_combi2_output, "Spacy-FSPOST Combi2")
# Out:
# Tagger:  Flair-FSPOST Combi1
# POS Tag:  NOUN  accuracy: 90.196078
# POS Tag:  PROPN  accuracy: 75.000000
# POS Tag:  PR  accuracy: 76.470588
# POS Tag:  DT  accuracy: 58.620690
# POS Tag:  CONJ  accuracy: 100.000000
# POS Tag:  IN  accuracy: 64.705882
# POS Tag:  VB  accuracy: 67.441860
# POS Tag:  JJ  accuracy: 50.000000
# POS Tag:  CD  accuracy: 88.888889
# POS Tag:  RB  accuracy: 89.473684
# POS Tag:  UH  accuracy: 100.000000
# POS Tag:  PUNC  accuracy: 94.871795
# POS Tag:  SYM  accuracy: 100.000000
# POS Tag:  EX  accuracy: 0.000000
# POS Tag:  TO  accuracy: 14.285714
# POS Tag:  MD  accuracy: 20.000000
#
#
# Tagger:  Spacy-FSPOST Combi1
# POS Tag:  NOUN  accuracy: 80.392157
# POS Tag:  PROPN  accuracy: 75.000000
# POS Tag:  PR  accuracy: 76.470588
# POS Tag:  DT  accuracy: 58.620690
# POS Tag:  CONJ  accuracy: 100.000000
# POS Tag:  IN  accuracy: 64.705882
# POS Tag:  VB  accuracy: 74.418605
# POS Tag:  JJ  accuracy: 50.000000
# POS Tag:  CD  accuracy: 100.000000
# POS Tag:  RB  accuracy: 89.473684
# POS Tag:  UH  accuracy: 50.000000
# POS Tag:  PUNC  accuracy: 94.871795
# POS Tag:  SYM  accuracy: 100.000000
# POS Tag:  EX  accuracy: 0.000000
# POS Tag:  TO  accuracy: 100.000000
# POS Tag:  MD  accuracy: 20.000000
#
#
# Tagger:  Flair-FSPOST Combi2
# POS Tag:  NOUN  accuracy: 90.196078
# POS Tag:  PROPN  accuracy: 75.000000
# POS Tag:  PR  accuracy: 88.235294
# POS Tag:  DT  accuracy: 58.620690
# POS Tag:  CONJ  accuracy: 100.000000
# POS Tag:  IN  accuracy: 88.235294
# POS Tag:  VB  accuracy: 83.720930
# POS Tag:  JJ  accuracy: 68.750000
# POS Tag:  CD  accuracy: 88.888889
# POS Tag:  RB  accuracy: 94.736842
# POS Tag:  UH  accuracy: 50.000000
# POS Tag:  PUNC  accuracy: 94.871795
# POS Tag:  SYM  accuracy: 100.000000
# POS Tag:  EX  accuracy: 100.000000
# POS Tag:  TO  accuracy: 85.714286
# POS Tag:  MD  accuracy: 20.000000
#
#
# Tagger:  Spacy-FSPOST Combi2
# POS Tag:  NOUN  accuracy: 82.352941
# POS Tag:  PROPN  accuracy: 75.000000
# POS Tag:  PR  accuracy: 82.352941
# POS Tag:  DT  accuracy: 58.620690
# POS Tag:  CONJ  accuracy: 100.000000
# POS Tag:  IN  accuracy: 82.352941
# POS Tag:  VB  accuracy: 79.069767
# POS Tag:  JJ  accuracy: 75.000000
# POS Tag:  CD  accuracy: 100.000000
# POS Tag:  RB  accuracy: 94.736842
# POS Tag:  UH  accuracy: 50.000000
# POS Tag:  PUNC  accuracy: 94.871795
# POS Tag:  SYM  accuracy: 100.000000
# POS Tag:  EX  accuracy: 100.000000
# POS Tag:  TO  accuracy: 85.714286
# POS Tag:  MD  accuracy: 20.000000

# %% [markdown]
# Genarating Confusion Matrix

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# %%
actual_tags = []
predicted_tags = []
for i in range(len(tags_list)):
    for j in range(len(tags_list[i])):
        actual_tags.append(tags_list[i][j])
        if (ff_combi1_output['general_tags'][i][j] == 'VB' or ff_combi1_output['general_tags'][i][j] == 'VBPT' or
                ff_combi1_output['general_tags'][i][j] == 'VBPR' or ff_combi1_output['general_tags'][i][j] == 'VBFT'):
            predicted_tags.append('VB')
        else:
            predicted_tags.append(ff_combi1_output['general_tags'][i][j])

# %%
# dataset_pos_tags = ['NOUN', 'PROPN', 'PR', 'DT', 'LM', 'CONJ', 'CCP', 'IN', 'VB', 'JJ', 'CD', 'RB', 'UH',
#                  'TS', 'FW', 'PUNC', 'SYM', 'EX', 'TO', 'POS', 'XX', 'MD']

# VERB
# dataset_pos_tags = ['NOUN', 'CONJ', 'VB', 'PR', 'JJ', 'RB', 'PUNC', 'DT', 'CCP', 'PROPN', 'MD', 'UH', 'CD', 'TO', 'LM', 'IN']

#Homographs
# dataset_pos_tags = ['NOUN', 'CONJ', 'VB', 'RB', 'PR', 'DT', 'PUNC', 'PROPN', 'JJ', 'CCP', 'CD', 'LM', 'SYM', 'IN', 'XX', 'UH', 'TO', 'MD', 'FW']

#monolingual-eng
dataset_pos_tags = ['NOUN', 'VB', 'PUNC', 'DT', 'RB', 'IN', 'PR', 'JJ', 'CD', 'TO', 'SYM', 'ND', 'CONJ', 'PROPN', 'UH', 'EX']

# %%
def clean_labels(label):
    return str(label).replace("['", '').replace("']", '')

# %%
def generate_confusion_matrix(combi):
    actual_tags = []
    predicted_tags = []
    for i in range(len(tags_list)):
        for j in range(len(tags_list[i])):
            actual_tags.append(tags_list[i][j])
            if (combi['general_tags'][i][j] == 'VB' or combi['general_tags'][i][j] == 'VBPT' or
                    combi['general_tags'][i][j] == 'VBPR' or combi['general_tags'][i][j] == 'VBFT'):
                predicted_tags.append('VB')
            else:
                predicted_tags.append(combi['general_tags'][i][j])
            
    np.seterr(invalid='ignore')
    plt.figure(figsize=(60, 40))
    plt.rcParams.update({'font.size': 32})
    cm = metrics.confusion_matrix(actual_tags, predicted_tags, labels=dataset_pos_tags, normalize='true')
    cm_df = pd.DataFrame(cm, columns=dataset_pos_tags)
    order = np.argsort(-cm_df.to_numpy().diagonal())
    
    label_df = pd.DataFrame(dataset_pos_tags)
    label_df = label_df.iloc[order].to_numpy()
    
    labels = []
    for i in range(len(label_df)):
        labels.append(clean_labels(label_df[i]))
    
    fx = sns.heatmap(cm_df.iloc[order, order], annot=True, fmt=".2f", cmap=plt.cm.Blues)
    fx.set_title('Confusion Matrix \n')
    fx.set_xlabel('\n Predicted Values\n')
    fx.set_ylabel('\n Actual Values\n')
    fx.xaxis.set_ticklabels(labels)
    fx.yaxis.set_ticklabels(labels)
    plt.show()
    
    print(metrics.classification_report(actual_tags, predicted_tags))

# %%
generate_confusion_matrix(ff_combi1_output)
# Out:
#               precision    recall  f1-score   support
#
#           CD       0.73      0.89      0.80         9
#         CONJ       0.57      1.00      0.73         4
#           DT       0.94      0.59      0.72        29
#           EX       0.00      0.00      0.00         1
#           FW       0.00      0.00      0.00         0
#           IN       1.00      0.65      0.79        17
#           JJ       0.89      0.50      0.64        16
#           MD       0.50      0.20      0.29         5
#         NOUN       0.63      0.90      0.74        51
#           PR       1.00      0.76      0.87        17
#        PROPN       0.33      0.75      0.46         4
#         PUNC       1.00      0.95      0.97        39
#           RB       0.77      0.89      0.83        19
#          SYM       1.00      1.00      1.00         6
#           TO       1.00      0.14      0.25         7
#           UH       0.29      1.00      0.44         2
#           VB       0.94      0.67      0.78        43
#           XX       0.00      0.00      0.00         0
#
#     accuracy                           0.75       269
#    macro avg       0.64      0.61      0.57       269
# weighted avg       0.85      0.75      0.77       269
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
generate_confusion_matrix(sf_combi1_output)
# Out:
#               precision    recall  f1-score   support
#
#           CD       0.75      1.00      0.86         9
#         CONJ       0.57      1.00      0.73         4
#           DT       0.94      0.59      0.72        29
#           EX       0.00      0.00      0.00         1
#           FW       0.00      0.00      0.00         0
#           IN       1.00      0.65      0.79        17
#           JJ       1.00      0.50      0.67        16
#           MD       0.50      0.20      0.29         5
#         NOUN       0.64      0.80      0.71        51
#           PR       1.00      0.76      0.87        17
#        PROPN       0.21      0.75      0.33         4
#         PUNC       1.00      0.95      0.97        39
#           RB       0.71      0.89      0.79        19
#          SYM       1.00      1.00      1.00         6
#           TO       1.00      1.00      1.00         7
#           UH       0.25      0.50      0.33         2
#           VB       0.89      0.74      0.81        43
#
#     accuracy                           0.77       269
#    macro avg       0.67      0.67      0.64       269
# weighted avg       0.84      0.77      0.78       269
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
generate_confusion_matrix(ff_combi2_output)
# Out:
#               precision    recall  f1-score   support
#
#           CD       0.80      0.89      0.84         9
#         CONJ       0.67      1.00      0.80         4
#           DT       0.94      0.59      0.72        29
#           EX       1.00      1.00      1.00         1
#           FW       0.00      0.00      0.00         0
#           IN       0.94      0.88      0.91        17
#           JJ       1.00      0.69      0.81        16
#           MD       0.50      0.20      0.29         5
#         NOUN       0.87      0.90      0.88        51
#           PR       1.00      0.88      0.94        17
#        PROPN       0.33      0.75      0.46         4
#         PUNC       0.95      0.95      0.95        39
#           RB       1.00      0.95      0.97        19
#          SYM       0.86      1.00      0.92         6
#           TO       1.00      0.86      0.92         7
#           UH       1.00      0.50      0.67         2
#           VB       0.97      0.84      0.90        43
#
#     accuracy                           0.84       269
#    macro avg       0.81      0.76      0.76       269
# weighted avg       0.92      0.84      0.87       269
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
generate_confusion_matrix(sf_combi2_output)
# Out:
#               precision    recall  f1-score   support
#
#           CD       0.82      1.00      0.90         9
#         CONJ       0.67      1.00      0.80         4
#           DT       0.89      0.59      0.71        29
#           EX       1.00      1.00      1.00         1
#           FW       0.00      0.00      0.00         0
#           IN       0.93      0.82      0.87        17
#           JJ       0.71      0.75      0.73        16
#           MD       0.50      0.20      0.29         5
#         NOUN       0.88      0.82      0.85        51
#           PR       1.00      0.82      0.90        17
#        PROPN       0.33      0.75      0.46         4
#         PUNC       0.97      0.95      0.96        39
#           RB       0.95      0.95      0.95        19
#          SYM       0.75      1.00      0.86         6
#           TO       1.00      0.86      0.92         7
#           UH       1.00      0.50      0.67         2
#           VB       0.97      0.79      0.87        43
#
#     accuracy                           0.81       269
#    macro avg       0.79      0.75      0.75       269
# weighted avg       0.90      0.81      0.84       269
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Adrian Jerez\Desktop\THESIS REPO\FIL-ENG-POST\project_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
